# %% [markdown]
# <a href="https://colab.research.google.com/github/LEJESHK/webscrap/blob/main/china.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup
import seaborn as sns
import pandas as pd
import requests
import openpyxl

# %%
base_url = 'https://www.booking.com/searchresults.en-gb.html?ss=China&ssne=China&ssne_untouched=China&label=gen173nr-1FCAEoggI46AdIM1gEaGyIAQGYAQm4ARfIAQzYAQHoAQH4AQuIAgGoAgO4AsX337AGwAIB0gIkOTVlYmY2ZjUtNWY2NS00YTI5LWI0NDItYmI5ODM2NmJiZDk52AIG4AIB&sid=2ecc9496d7bc7c3fb51da90502564919&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=44&dest_type=country&checkin=2024-04-18&checkout=2024-04-24&group_adults=2&no_rooms=1&group_children=0'

headers = {
    'User-Agent': 'Mozilla/5.0 (X11; CrOS x86_64 8172.45.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.64 Safari/537.36',
    'Accept-Language': 'en-US, en;q=0.5'
}

# %%
hotel_results = []

# %%
for page_number in range(0, 250,25):
    url = base_url.format(page_number)

    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
for el in soup.find_all("div", {"data-testid": "property-card"}):
    hotel_results.append({
        'name':el.find("div", {"data-testid": "title"}).text.strip(),
        'description': el.find('div', {'data-testid': 'recommended-units', 'class': 'ccdd44706b'}).text.strip(),
        "location": el.find("span", {"data-testid": "address"}).text.strip(),
        "pricing": el.find("span", {"data-testid": "price-and-discounted-price"}).text.strip(),
        "rating": el.find("div", {"data-testid": "review-score"}).text.strip().split(" ")[0],
    })

# Create DataFrame from the collected results
hotels = pd.DataFrame(hotel_results)

# %%
hotels.to_excel('datp.xlsx',index=False)

# %%
from google.colab import files
files.download('datp.xlsx')

# %%
hotels.head()
# Out:
#                                                 name  \
# 0           Arthur Hotel Zhujiang New Town Guangzhou
# 1                                   White Swan Hotel
# 2               Pengman Beijing Rd. A-mall Apartment
# 3                       Imperial Traders Elong Hotel
# 4  Hampton by Hilton Guangzhou Renhe Baiyun Airpo...
#
#                                          description  \
# 0  Arthur Standard Room King Bed (No Window）1 ext...
# 1  Special Offer - Standard Twin Room2 single bed...
# 2  Deluxe Twin StudioEntire studio • 1 bathroom •...
# 3             Standard Double Room1 large double bed
# 4  Standard Double Room1 large double bedBreakfas...
#
#                      location     pricing     rating
# 0          Tian He, Guangzhou  TWD 40,074  8.8Scored
# 1           Li Wan, Guangzhou  TWD 50,451  8.9Scored
# 2          Yue Xiu, Guangzhou  TWD 17,816  7.6Scored
# 3          Yue Xiu, Guangzhou  TWD 30,251  8.4Scored
# 4  Baiyun District, Guangzhou  TWD 16,203  8.0Scored
