# %% [markdown]
# <a href="https://colab.research.google.com/github/LEJESHK/webscrap/blob/main/salem_webscrap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup
import seaborn as sns
import pandas as pd
import requests
import openpyxl

# %%
base_url = 'https://www.booking.com/searchresults.en-gb.html?ss=Salem%2C+Tamil+Nadu%2C+India&ssne=Hyderabad&ssne_untouched=Hyderabad&label=gen173nr-1FCAEoggI46AdIM1gEaGyIAQGYAQm4ARfIAQzYAQHoAQH4AQuIAgGoAgO4AsX337AGwAIB0gIkOTVlYmY2ZjUtNWY2NS00YTI5LWI0NDItYmI5ODM2NmJiZDk52AIG4AIB&sid=2ecc9496d7bc7c3fb51da90502564919&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=-2109974&dest_type=city&ac_position=0&ac_click_type=b&ac_langcode=en&ac_suggestion_list_length=5&search_selected=true&search_pageview_id=deb96b4bc18d066e&ac_meta=GhBkNmE2NmI5YTdjZTIwMDEyIAAoATICZW46BXNhbGVtQABKAFAA&checkin=2024-04-18&checkout=2024-04-24&group_adults=2&no_rooms=1&group_children=0'
headers = {
    'User-Agent': 'Mozilla/5.0 (X11; CrOS x86_64 8172.45.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.64 Safari/537.36',
    'Accept-Language': 'en-US, en;q=0.5'
}

# %%
hotel_results = []

# %%
for page_number in range(0, 250,25):
    url = base_url.format(page_number)
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
for el in soup.find_all("div", {"data-testid": "property-card"}):
    hotel_results.append({
        'name':el.find("div", {"data-testid": "title"}).text.strip(),
        'description': el.find('div', {'data-testid': 'recommended-units', 'class': 'ccdd44706b'}).text.strip(),
        "location": el.find("span", {"data-testid": "address"}).text.strip(),
        "pricing": el.find("span", {"data-testid": "price-and-discounted-price"}).text.strip(),
        #"rating": el.find("div", {"data-testid": "review-score"}).text.strip().split(" ")[0],
    })
# Create DataFrame from the collected results
hotels = pd.DataFrame(hotel_results)

# %%
hotels.to_excel('datp.xlsx',index=False)

# %%
from google.colab import files
files.download('datp.xlsx')

# %%
hotels.head()
# Out:
#                        name  \
# 0  ZIBE Salem By GRT Hotels
# 1            Radisson Salem
# 2     Hotel Cenneys Gateway
# 3         Sivaraj Inn Salem
# 4       Hotel Shrie Shaanth
#
#                                          description location pricing  \
# 0  Superior Double Room1 extra-large double bedBr...    Salem  US$279
# 1                          Superior Room1 double bed    Salem  US$398
# 2  Club Double Room1 extra-large double bedFree c...    Salem  US$394
# 3  Budget Double Room1 double bedFree cancellatio...    Salem  US$274
# 4  Superior Double Room1 extra-large double bedBr...    Salem  US$221
#
#       rating
# 0  8.2Scored
# 1  8.7Scored
# 2  7.0Scored
# 3  7.1Scored
# 4  7.8Scored
