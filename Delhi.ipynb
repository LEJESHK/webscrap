# %% [markdown]
# <a href="https://colab.research.google.com/github/LEJESHK/webscrap/blob/main/Delhi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup
import seaborn as sns
import pandas as pd
import requests
import openpyxl

# %%
base_url = 'https://www.booking.com/searchresults.en-gb.html?ss=New+Delhi&ssne=New+Delhi&ssne_untouched=New+Delhi&label=gen173nr-1FCAEoggI46AdIM1gEaGyIAQGYAQm4ARfIAQzYAQHoAQH4AQuIAgGoAgO4AsX337AGwAIB0gIkOTVlYmY2ZjUtNWY2NS00YTI5LWI0NDItYmI5ODM2NmJiZDk52AIG4AIB&sid=2ecc9496d7bc7c3fb51da90502564919&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=-2106102&dest_type=city&checkin=2024-04-18&checkout=2024-04-24&group_adults=2&no_rooms=1&group_children=0'

headers = {
    'User-Agent': 'Mozilla/5.0 (X11; CrOS x86_64 8172.45.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.64 Safari/537.36',
    'Accept-Language': 'en-US, en;q=0.5'
}

# %%
hotel_results = []

# %%
for page_number in range(0, 250,25):
    url = base_url.format(page_number)

    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
for el in soup.find_all("div", {"data-testid": "property-card"}):
    hotel_results.append({
        'name':el.find("div", {"data-testid": "title"}).text.strip(),
        'description': el.find('div', {'data-testid': 'recommended-units', 'class': 'ccdd44706b'}).text.strip(),
        "location": el.find("span", {"data-testid": "address"}).text.strip(),
        "pricing": el.find("span", {"data-testid": "price-and-discounted-price"}).text.strip(),
        "rating": el.find("div", {"data-testid": "review-score"}).text.strip().split(" ")[0],
    })

# Create DataFrame from the collected results
hotels = pd.DataFrame(hotel_results)

# %%
hotels.to_excel('datp.xlsx',index=False)

# %%
from google.colab import files
files.download('datp.xlsx')

# %%
hotels.head()
# Out:
#                                               name  \
# 0               FabExpress Jaggi Palace Karol Bagh
# 1  Hotel Delhi 37 by Star Group NEAR DELHI AIRPORT
# 2               Hotel Green Leaf - Sarai Kale Khan
# 3                     Suites Admiral Delhi Airport
# 4                                 Hotel Blue Pearl
#
#                                          description                location  \
# 0  Deluxe Room1 double bedFree cancellationOnly 2...   Karol bagh, New Delhi
# 1  Double Room1 double bedBreakfast includedFree ...   Mahipalpur, New Delhi
# 2  Deluxe Double Room (2 Adults + 1 Child)1 doubl...  South Delhi, New Delhi
# 3  Deluxe Double Room1 extra-large double bedFree...   South West, New Delhi
# 4  Deluxe Room1 double bedBreakfast includedOnly ...    Paharganj, New Delhi
#
#      pricing     rating
# 0  TWD 4,190  7.7Scored
# 1  TWD 6,721  9.0Scored
# 2  TWD 2,251  7.8Scored
# 3  TWD 2,306  7.2Scored
# 4  TWD 4,675  7.9Scored
